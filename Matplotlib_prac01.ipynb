# %%
# %matplotlib notebook
import matplotlib as mpl
mpl.get_backend()
# Out:
# 'nbAgg'

# %%
import matplotlib.pyplot as plt
plt.plot?

# %%
import numpy as np
plt.figure()

languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
pos = np.arange(len(languages))
popularity = [56, 39, 34, 34, 29]
r = plt.bar(pos, popularity, align='center', 
        color = ['#1F77B4',"#778899","#778899","#778899","#778899"])
plt.xticks(pos, languages)
plt.ylabel('% Popularity')
plt.title('Top 5 Languages for Math & Data', alpha=0.8)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Top 5 Languages for Math & Data')

# %%
# ticks & label remove
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)

plt.tick_params(axis='x', direction = 'out', color = 'white')

plt.gca().axes.yaxis.set_visible(False)
#plt.gca().axes.xaxis.set_visible(False)


plt.yticks(ticks = [])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
# 퍼센테이지 표현
for index, value in enumerate(r):
    plt.text(value.get_x() + value.get_width()/2, value.get_height() -5,
             str(popularity[index]) + '%', ha = 'center',color = 'white')
plt.show()
